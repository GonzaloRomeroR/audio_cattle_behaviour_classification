# %% [markdown]
# ## Sound classification

# %%
import os
import sys

from sound_utils import *
from filter import *

# %%
file_name = "audios_recording_01"
sample_rate, data = upload_audio_file(f"../data/{file_name}.wav")
plot_audio(data, sample_rate)
# Out:
# c:\Users\gonza\OneDrive\Documentos\Gonzalo\Especializacion\inteligencia_embebida\esp32_loopback\python\sound_utils.py:9: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   return wavfile.read(path)

# %%
filter_ma = MovingAverage(window_size=5000)
filtered_data = []

for value in data:
    absolute = abs(value) if abs(value) >= 0 else np.iinfo(value.dtype).max
    filtered_data.append(filter_ma.calculate_ma(absolute))
plot_audio(filtered_data, sample_rate)
